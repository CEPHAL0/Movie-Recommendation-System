# %% [markdown]
# # Importing the data:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np

# %% [markdown]
# Importing the datasets:

# %%
import os
for dirname, _, filenames in os.walk('./datasets'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# ./datasets\archive.zip
# ./datasets\tmdb_5000_credits.csv
# ./datasets\tmdb_5000_movies.csv

# %% [markdown]
# # Data Info

# %%
movie = pd.read_csv('./datasets/tmdb_5000_credits.csv')
credits = pd.read_csv('./datasets/tmdb_5000_movies.csv')

display(movie.head(3))
display(credits.head(3))
display(movie.columns.tolist())
display(credits.columns.tolist())
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
# ...

# %% [markdown]
# # About Data:
# ## Movies Data:
# Movies data contains 3 columns:
# 1. movie_id = unique identifier for movie_id
# 2. title
# 3. cast = cast of the movie (in json format)
# 4. crew = crew who worked in the movie (in json format)
# ## Credits Data:
# It consists of lot of columns with various properties of the movie

# %% [markdown]
# # Parsing the JSON data

# %% [markdown]
# Parsing the **cast** and seeing its format:
# We can see that the cast column is a json, lets unpack the json and see how data is stored inside it.

# %%
jsonText = movie.cast[1]
import json
y = json.loads(jsonText)
for dicts in y:
    for key,values in dicts.items():
        print(f'{key}: {values}')
    print('\n')
# Out:
# cast_id: 4
# character: Captain Jack Sparrow
# credit_id: 52fe4232c3a36847f800b50d
# gender: 2
# id: 85
# name: Johnny Depp
# order: 0
#
#
# cast_id: 5
# character: Will Turner
# credit_id: 52fe4232c3a36847f800b511
# gender: 2
# id: 114
# name: Orlando Bloom
# order: 1
#
#
# cast_id: 6
# character: Elizabeth Swann
# credit_id: 52fe4232c3a36847f800b515
# gender: 1
# id: 116
# name: Keira Knightley
# order: 2
#
#
# cast_id: 12
# character: William "Bootstrap Bill" Turner
# credit_id: 52fe4232c3a36847f800b52d
# gender: 2
# id: 1640
# name: Stellan Skarsgård
# order: 3
#
#
# cast_id: 10
# character: Captain Sao Feng
# credit_id: 52fe4232c3a36847f800b525
# gender: 2
# id: 1619
# name: Chow Yun-fat
# order: 4
#
#
# cast_id: 9
# character: Captain Davy Jones
# credit_id: 52fe4232c3a36847f800b521
# gender: 2
# id: 2440
# name: Bill Nighy
# order: 5
#
#
# cast_id: 7
# character: Captain Hector Barbossa
# credit_id: 52fe4232c3a36847f800b519
# gender: 2
# id: 118
# name: Geoffrey Rush
# ...

# %% [markdown]
# Parsing the **crew** and seeing its format:
# We can see that the crew column is a json, lets unpack the json and see how data is stored inside it.

# %%
# Making a function that unpacks a json and produces the output
def unparse(jsonList):
    y = json.loads(jsonList)
    for dicts in y:
        for key,values in dicts.items():
            print(f'{key}: {values}')
        print('\n')

# %%
unparse(movie.crew[1])
# Out:
# credit_id: 52fe4232c3a36847f800b579
# department: Camera
# gender: 2
# id: 120
# job: Director of Photography
# name: Dariusz Wolski
#
#
# credit_id: 52fe4232c3a36847f800b4fd
# department: Directing
# gender: 2
# id: 1704
# job: Director
# name: Gore Verbinski
#
#
# credit_id: 52fe4232c3a36847f800b54f
# department: Production
# gender: 2
# id: 770
# job: Producer
# name: Jerry Bruckheimer
#
#
# credit_id: 52fe4232c3a36847f800b503
# department: Writing
# gender: 2
# id: 1705
# job: Screenplay
# name: Ted Elliott
#
#
# credit_id: 52fe4232c3a36847f800b509
# department: Writing
# gender: 2
# id: 1706
# job: Screenplay
# name: Terry Rossio
#
#
# credit_id: 52fe4232c3a36847f800b57f
# department: Editing
# gender: 0
# id: 1721
# job: Editor
# name: Stephen E. Rivkin
#
#
# credit_id: 52fe4232c3a36847f800b585
# department: Editing
# gender: 2
# id: 1722
# job: Editor
# name: Craig Wood
#
#
# credit_id: 52fe4232c3a36847f800b573
# department: Sound
# gender: 2
# id: 947
# ...

# %%
unparse(credits.genres[1])
# Out:
# id: 12
# name: Adventure
#
#
# id: 14
# name: Fantasy
#
#
# id: 28
# name: Action

# %%
unparse(credits.production_companies[1])
# Out:
# name: Walt Disney Pictures
# id: 2
#
#
# name: Jerry Bruckheimer Films
# id: 130
#
#
# name: Second Mate Productions
# id: 19936

# %%
unparse(credits.production_countries[1])
# Out:
# iso_3166_1: US
# name: United States of America

# %%
unparse(credits.keywords[1])
# Out:
# id: 270
# name: ocean
#
#
# id: 726
# name: drug abuse
#
#
# id: 911
# name: exotic island
#
#
# id: 1319
# name: east india trading company
#
#
# id: 2038
# name: love of one's life
#
#
# id: 2052
# name: traitor
#
#
# id: 2580
# name: shipwreck
#
#
# id: 2660
# name: strong woman
#
#
# id: 3799
# name: ship
#
#
# id: 5740
# name: alliance
#
#
# id: 5941
# name: calypso
#
#
# id: 6155
# name: afterlife
#
#
# id: 6211
# name: fighter
#
#
# id: 12988
# name: pirate
#
#
# id: 157186
# name: swashbuckler
#
#
# id: 179430
# name: aftercreditsstinger

# %%
unparse(credits.spoken_languages[1])
# Out:
# iso_639_1: en
# name: English

# %% [markdown]
# # Concatening the data
# The **credits** and **movie** datasets can be merged into one dataset on the **movie_id** and **id** respectively

# %%
mergeddf = movie.merge(credits, on='title')
mergeddf.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  ...  \
# ...

# %%
display(mergeddf.shape)
display(mergeddf.dtypes)
# Out:
# (4809, 23)
# movie_id                  int64
# title                    object
# cast                     object
# crew                     object
# budget                    int64
# genres                   object
# homepage                 object
# id                        int64
# keywords                 object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# production_companies     object
# production_countries     object
# release_date             object
# revenue                   int64
# runtime                 float64
# spoken_languages         object
# status                   object
# tagline                  object
# vote_average            float64
# vote_count                int64
# dtype: object

# %% [markdown]
# # Dropping Columns

# %% [markdown]
# We don't have to drop any columns except the ID column since it is repeated, apart from that we see that all columns are equally important for classifying and making keywords.

# %%
df = mergeddf.drop(columns=['id'])
df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew     budget  \
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...  237000000
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...  300000000
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...  245000000
# ...

# %% [markdown]
# # Features and Columns to engineer
# We can use the following columns to make recommendations as a basis:
#     1. cast
#     2. genres
#     3. keywords
#     4. overview
#     5. *popularity : non text*
#     6. *release_date : non text*
#     7. *runtime : non text*
#     8. spoken_language
#     9. title
#     10.crew
#
# We donot keep tagline because tagline tend to be more stylish and not really fit the reality of the movie.

# %%
# Extracting the columns
cols = ['movie_id','cast', 'genres', 'overview','release_date','runtime','title','crew']
df_filtered = df[cols]
df_filtered.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1       285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2    206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3     49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4     49529  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview release_date  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10    162.0
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19    169.0
# ...

# %% [markdown]
# # Preprocessing
# We have to preprocess the data in a format where it contains only three columns:
# > Title
# > ID
# > Tags
# **Tags** column is created by taking the following properties and making them into a list:
# 1. cast : top 3 casts
# 2. genres : all genres
# 3. overview : all words splitted and added into a single list
# 4. crew : director's name

# %%
movpre = df_filtered.copy()
movpre.columns
# Out:
# Index(['movie_id', 'cast', 'genres', 'overview', 'release_date', 'runtime',
#        'title', 'crew'],
#       dtype='object')

# %%
movpre.info
# Out:
# <bound method DataFrame.info of       movie_id                                               cast  \
# 0        19995  [{"cast_id": 242, "character": "Jake Sully", "...
# 1          285  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2       206647  [{"cast_id": 1, "character": "James Bond", "cr...
# 3        49026  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4        49529  [{"cast_id": 5, "character": "John Carter", "c...
# ...        ...                                                ...
# 4804      9367  [{"cast_id": 1, "character": "El Mariachi", "c...
# 4805     72766  [{"cast_id": 1, "character": "Buzzy", "credit_...
# 4806    231617  [{"cast_id": 8, "character": "Oliver O\u2019To...
# 4807    126186  [{"cast_id": 3, "character": "Sam", "credit_id...
# 4808     25975  [{"cast_id": 3, "character": "Herself", "credi...
#
#                                                  genres  \
# 0     [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
movpre.isna().sum()
# Out:
# movie_id        0
# cast            0
# genres          0
# overview        3
# release_date    1
# runtime         2
# title           0
# crew            0
# dtype: int64

# %%
movpre.shape
# Out:
# (4809, 8)

# %%
# Checking the data where release date is missing
display(movpre[movpre.release_date.isnull()])
# Out:
#       movie_id cast genres                                           overview  \
# 4559    380097   []     []  1971 post civil rights San Francisco seemed li...
#
#      release_date  runtime                       title crew
# 4559          NaN      0.0  America Is Still the Place   []

# %% [markdown]
# Lets fix that by doing some research:
# After googling we found the release date for the movie **America is Still the Place** is June 10, 2022
# We couldnt find the details about other columns, so unfortunately we'd have to drop it.

# %%
movpre.drop(index=4559, inplace=True)

# %%
movpre.isna().sum()
# Out:
# movie_id        0
# cast            0
# genres          0
# overview        3
# release_date    0
# runtime         2
# title           0
# crew            0
# dtype: int64

# %% [markdown]
# We have to fix the runtime of those 2 missing values.

# %%
# retrieving the data which doesnot have run time
display(movpre[movpre.runtime.isnull()])
# Out:
#       movie_id                                               cast  \
# 2662    370980  [{"cast_id": 5, "character": "Jorge Mario Berg...
# 4147    459488  [{"cast_id": 0, "character": "Narrator", "cred...
#
#                                    genres overview release_date  runtime  \
# 2662        [{"id": 18, "name": "Drama"}]      NaN   2015-12-03      NaN
# 4147  [{"id": 99, "name": "Documentary"}]      NaN   2015-12-12      NaN
#
#                                            title  \
# 2662  Chiamatemi Francesco - Il Papa della gente
# 4147                 To Be Frank, Sinatra at 100
#
#                                                    crew
# 2662  [{"credit_id": "5660019ac3a36875f100252b", "de...
# 4147  [{"credit_id": "592b25e4c3a368783e065a2f", "de...

# %% [markdown]
# The run time of the movie **Chiamatemi Francesco - Il Papa della gente** is **1h38m** and the runtime of the movie **To Be Frank, Sinatra at 100** is **1h21m**.

# %%
movpre.loc[movpre.title == 'Chiamatemi Francesco - Il Papa della gente', 'runtime'] = 98.0
movpre.loc[movpre.title == 'To Be Frank, Sinatra at 100','runtime'] = 81.0

# Also adding other missing values like overview
movpre.loc[movpre.title == 'Chiamatemi Francesco - Il Papa della gente', 'overview'] = 'The story of Pope Francis life'
movpre.loc[movpre.title == 'To Be Frank, Sinatra at 100','overview']='The life of Frank Sinatra, as an actor and singer and the steps along the way that led him to become such an icon'

display(movpre.loc[movpre.title == 'Chiamatemi Francesco - Il Papa della gente'])
display(movpre.loc[movpre.title == 'Chiamatemi Francesco - Il Papa della gente'])
# Out:
#       movie_id                                               cast  \
# 2662    370980  [{"cast_id": 5, "character": "Jorge Mario Berg...
#
#                              genres                        overview  \
# 2662  [{"id": 18, "name": "Drama"}]  The story of Pope Francis life
#
#      release_date  runtime                                       title  \
# 2662   2015-12-03     98.0  Chiamatemi Francesco - Il Papa della gente
#
#                                                    crew
# 2662  [{"credit_id": "5660019ac3a36875f100252b", "de...
#       movie_id                                               cast  \
# 2662    370980  [{"cast_id": 5, "character": "Jorge Mario Berg...
#
#                              genres                        overview  \
# 2662  [{"id": 18, "name": "Drama"}]  The story of Pope Francis life
#
#      release_date  runtime                                       title  \
# 2662   2015-12-03     98.0  Chiamatemi Francesco - Il Papa della gente
#
# ...

# %%
movpre.isnull().sum()
# Out:
# movie_id        0
# cast            0
# genres          0
# overview        1
# release_date    0
# runtime         0
# title           0
# crew            0
# dtype: int64

# %%
movpre.loc[movpre.overview.isnull()]
# Out:
#       movie_id cast                               genres overview  \
# 4437    292539   []  [{"id": 99, "name": "Documentary"}]      NaN
#
#      release_date  runtime        title  \
# 4437   2014-04-26     83.0  Food Chains
#
#                                                    crew
# 4437  [{"credit_id": "5470c3b1c3a368085e000abd", "de...

# %% [markdown]
# We add the overview into this movie

# %%
movpre.loc[movpre.overview.isnull(),'overview']='To protest their working conditions and poor wages, farmworkers in Immokalee, Florida, start a hunger strike outside the headquarters of Publix supermarkets'
movpre.loc[movpre.title=='Food Chains']
# Out:
#       movie_id cast                               genres  \
# 4437    292539   []  [{"id": 99, "name": "Documentary"}]
#
#                                                overview release_date  runtime  \
# 4437  To protest their working conditions and poor w...   2014-04-26     83.0
#
#             title                                               crew
# 4437  Food Chains  [{"credit_id": "5470c3b1c3a368085e000abd", "de...

# %%
movpre.isnull().sum()
# Out:
# movie_id        0
# cast            0
# genres          0
# overview        0
# release_date    0
# runtime         0
# title           0
# crew            0
# dtype: int64

# %% [markdown]
# Now the data doesnot have any null values.

# %%
# Checking for duplicates
movpre.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Great, there are no duplicates as well.
# Now we can move into our next phase of deparsing the json

# %% [markdown]
# # Converting JSON to Lists

# %%
# Cast column
movpre.iloc[0].cast
# Out:
# '[{"cast_id": 242, "character": "Jake Sully", "credit_id": "5602a8a7c3a3685532001c9a", "gender": 2, "id": 65731, "name": "Sam Worthington", "order": 0}, {"cast_id": 3, "character": "Neytiri", "credit_id": "52fe48009251416c750ac9cb", "gender": 1, "id": 8691, "name": "Zoe Saldana", "order": 1}, {"cast_id": 25, "character": "Dr. Grace Augustine", "credit_id": "52fe48009251416c750aca39", "gender": 1, "id": 10205, "name": "Sigourney Weaver", "order": 2}, {"cast_id": 4, "character": "Col. Quaritch", "credit_id": "52fe48009251416c750ac9cf", "gender": 2, "id": 32747, "name": "Stephen Lang", "order": 3}, {"cast_id": 5, "character": "Trudy Chacon", "credit_id": "52fe48009251416c750ac9d3", "gender": 1, "id": 17647, "name": "Michelle Rodriguez", "order": 4}, {"cast_id": 8, "character": "Selfridge", "credit_id": "52fe48009251416c750ac9e1", "gender": 2, "id": 1771, "name": "Giovanni Ribisi", "order": 5}, {"cast_id": 7, "character": "Norm Spellman", "credit_id": "52fe48009251416c750ac9dd", "gender"
# ...

# %% [markdown]
# Lets make a function to parse the json and retrieve the top 4 cast and their names only

# %%
import json
def getcast(castJson):
    nameList = []
    castJson = json.loads(castJson)
    for i in range(min(4, len(castJson))):
        castItem = castJson[i]
        nameList.append(castItem['name'])
    return nameList


cast2 = getcast(movpre.iloc[0].cast)
cast2
# Out:
# ['Sam Worthington', 'Zoe Saldana', 'Sigourney Weaver', 'Stephen Lang']

# %% [markdown]
# Great now lets convert the cast column into a list of names:

# %%
movpre['cast'] = movpre['cast'].apply(getcast)
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                             overview release_date  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10    162.0
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19    169.0
# ...

# %% [markdown]
# Lets convert the genres columns into a list of genres

# %%
# Genre column
movpre.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# Function to generate genres list
def getGenre(obj):
    genreList = []
    genreJson = json.loads(obj)
    for i in range(len(genreJson)):
        genreList.append(genreJson[i]['name'])
    return genreList

genres = getGenre(movpre.iloc[0].genres)
genres
# Out:
# ['Action', 'Adventure', 'Fantasy', 'Science Fiction']

# %%
movpre.genres = movpre.genres.apply(getGenre)
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview release_date  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10    162.0
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19    169.0
# ...

# %% [markdown]
# Lets do the  same for the crew column, but lets retrieve the director name only:

# %%
# Crew column
movpre.iloc[0].crew
# Out:
# '[{"credit_id": "52fe48009251416c750aca23", "department": "Editing", "gender": 0, "id": 1721, "job": "Editor", "name": "Stephen E. Rivkin"}, {"credit_id": "539c47ecc3a36810e3001f87", "department": "Art", "gender": 2, "id": 496, "job": "Production Design", "name": "Rick Carter"}, {"credit_id": "54491c89c3a3680fb4001cf7", "department": "Sound", "gender": 0, "id": 900, "job": "Sound Designer", "name": "Christopher Boyes"}, {"credit_id": "54491cb70e0a267480001bd0", "department": "Sound", "gender": 0, "id": 900, "job": "Supervising Sound Editor", "name": "Christopher Boyes"}, {"credit_id": "539c4a4cc3a36810c9002101", "department": "Production", "gender": 1, "id": 1262, "job": "Casting", "name": "Mali Finn"}, {"credit_id": "5544ee3b925141499f0008fc", "department": "Sound", "gender": 2, "id": 1729, "job": "Original Music Composer", "name": "James Horner"}, {"credit_id": "52fe48009251416c750ac9c3", "department": "Directing", "gender": 2, "id": 2710, "job": "Director", "name": "James Cameron"
# ...

# %%
# Making a function
def getDirector(obj):
    director = []
    crewJson = json.loads(obj)
    for i in range(len(crewJson)):
        crew = crewJson[i]
        if crew['job']=='Director':
            director.append(crew['name'])
    return director

director = getDirector(movpre.iloc[0].crew)
director
# Out:
# ['James Cameron']

# %%
# Applying the function
movpre.crew = movpre.crew.apply(getDirector)
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview release_date  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...   2009-12-10    162.0
# 1  Captain Barbossa, long believed to be dead, ha...   2007-05-19    169.0
# ...

# %% [markdown]
# Now we convert the overview column into a list of words and store it as a list

# %%
# Overview column
movpre.iloc[0].overview
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization.'

# %%
# Making a function
def getOverview(string):
    overviewList = string.split(' ')
    return overviewList

getOverview('Hello there, this is a cool list.')
# Out:
# ['Hello', 'there,', 'this', 'is', 'a', 'cool', 'list.']

# %%
# Applying the function
movpre.overview = movpre.overview.apply(getOverview)
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview release_date  runtime  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...   2009-12-10    162.0
# 1  [Captain, Barbossa,, long, believed, to, be, d...   2007-05-19    169.0
# ...

# %%
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview release_date  runtime  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...   2009-12-10    162.0
# 1  [Captain, Barbossa,, long, believed, to, be, d...   2007-05-19    169.0
# ...

# %% [markdown]
# Lets convert the release date into a column with list of the release year only

# %%
def getYear(obj):
    year = []
    year.append(obj.split('-')[0])
    return year

getYear('2002-10-10')
# Out:
# ['2002']

# %%
# Applying the function
movpre.release_date = movpre.release_date.apply(getYear)
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview release_date  runtime  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...       [2009]    162.0
# 1  [Captain, Barbossa,, long, believed, to, be, d...       [2007]    169.0
# ...

# %% [markdown]
# # Making a new dataframe

# %%
# Concatening into one data column
movpre['tags'] = movpre['cast'] + movpre['genres'] + movpre['overview'] + movpre['release_date'] + movpre['crew']
movpre.head()
# Out:
#    movie_id                                               cast  \
# 0     19995  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1       285  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2    206647  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3     49026  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4     49529  [Taylor Kitsch, Lynn Collins, Samantha Morton,...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             overview release_date  runtime  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...       [2009]    162.0
# 1  [Captain, Barbossa,, long, believed, to, be, d...       [2007]    169.0
# ...

# %%
newdf = movpre[['movie_id','title','tags']]
newdf.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...

# %%
newdf.tags[0]
# Out:
# ['Sam Worthington',
#  'Zoe Saldana',
#  'Sigourney Weaver',
#  'Stephen Lang',
#  'Action',
#  'Adventure',
#  'Fantasy',
#  'Science Fiction',
#  'In',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'Marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'Pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  '2009',
#  'James Cameron']

# %%
newdf['tags']=newdf['tags'].apply(lambda x : [i.lower() for i in x])
newdf.head()
# Out:
# C:\Users\xarad\AppData\Local\Temp\ipykernel_10348\1980002674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['tags']=newdf['tags'].apply(lambda x : [i.lower() for i in x])
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  [sam worthington, zoe saldana, sigourney weave...
# 1  [johnny depp, orlando bloom, keira knightley, ...
# 2  [daniel craig, christoph waltz, léa seydoux, r...
# ...

# %%
newdf.tags[0]
# Out:
# ['sam worthington',
#  'zoe saldana',
#  'sigourney weaver',
#  'stephen lang',
#  'action',
#  'adventure',
#  'fantasy',
#  'science fiction',
#  'in',
#  'the',
#  '22nd',
#  'century,',
#  'a',
#  'paraplegic',
#  'marine',
#  'is',
#  'dispatched',
#  'to',
#  'the',
#  'moon',
#  'pandora',
#  'on',
#  'a',
#  'unique',
#  'mission,',
#  'but',
#  'becomes',
#  'torn',
#  'between',
#  'following',
#  'orders',
#  'and',
#  'protecting',
#  'an',
#  'alien',
#  'civilization.',
#  '2009',
#  'james cameron']

# %% [markdown]
# # Machine Learning Imports

# %%
import nltk
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %% [markdown]
# Making function for stemming of words

# %%
# Stemming the words
def stem(text):
    y = []
    
    for i in text.split():
        y.append(ps.stem(i))
        
    return " ".join(y)
stem('in this movie i am a batman')
stem('dance dances dancing dancer dancingball')
# Out:
# 'danc danc danc dancer dancingbal'

# %% [markdown]
# # Tokenization and Stemming of Words

# %%
# Converting the list to string first
newdf['tags'] = newdf.tags.apply(lambda x: ' '.join(x))
newdf.head()
# Out:
# C:\Users\xarad\AppData\Local\Temp\ipykernel_10348\2976025804.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf['tags'] = newdf.tags.apply(lambda x: ' '.join(x))
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  sam worthington zoe saldana sigourney weaver s...
# 1  johnny depp orlando bloom keira knightley stel...
# 2  daniel craig christoph waltz léa seydoux ralph...
# ...

# %% [markdown]
# Now, lets vectorize the words and convert it into numbers.

# %% [markdown]
# We extract the top 5000 words from the tags

# %%
# Stemming words
newdf.tags = newdf.tags.apply(stem)
newdf.head()
# Out:
# C:\Users\xarad\AppData\Local\Temp\ipykernel_10348\798749718.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf.tags = newdf.tags.apply(stem)
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  sam worthington zoe saldana sigourney weaver s...
# 1  johnni depp orlando bloom keira knightley stel...
# 2  daniel craig christoph waltz léa seydoux ralph...
# ...

# %%
newdf.tags.sample(1)
# Out:
# 4662    staci keach pia zadora orson well ed mcmahon c...
# Name: tags, dtype: object

# %% [markdown]
# # Vectorization of Words

# %% [markdown]
# We vectorize the tags using the CountVectorizer library and then vectorize the given tagline adn convert into numpy array.

# %% [markdown]
# Most of the array will consist of 0s because not all the movie contains the 5000 words as its tags. It will only have selected words.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000 ,stop_words= 'english')

# %%
vectors = cv.fit_transform(newdf['tags']).toarray()

# %%
display(vectors.shape)
display(vectors[0])
display(vectors[0].shape)
display(len(cv.get_feature_names_out()))
display(cv.get_feature_names_out())
# Out:
# (4808, 5000)
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)
# (5000,)
# 5000
# array(['000', '007', '10', ..., 'zucker', 'zwick', 'åkerman'],
#       dtype=object)

# %% [markdown]
# # Calculating Similarity using cosine distance

# %% [markdown]
# Using cosine distances -- distance between two movies.

# %% [markdown]
# Cosine Distance: Distance between 2 vectors as an angle

# %% [markdown]
# Distance is inversely proportional to similarity -> high similarity, low distance

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity = cosine_similarity(vectors)
display(similarity)
display(similarity.shape)
# Out:
# array([[1.        , 0.10910895, 0.10050378, ..., 0.        , 0.05287011,
#         0.        ],
#        [0.10910895, 1.        , 0.06579517, ..., 0.02595871, 0.        ,
#         0.02326211],
#        [0.10050378, 0.06579517, 1.        , ..., 0.0239114 , 0.09564562,
#         0.        ],
#        ...,
#        [0.        , 0.02595871, 0.0239114 , ..., 1.        , 0.03773585,
#         0.03381583],
#        [0.05287011, 0.        , 0.09564562, ..., 0.03773585, 1.        ,
#         0.06763167],
#        [0.        , 0.02326211, 0.        , ..., 0.03381583, 0.06763167,
#         1.        ]])
# (4808, 4808)

# %% [markdown]
# Here, we have a matrix this represents an array or arrays, where each array is the distance between a given movie and all other movies. So the shape of the array is 4808x4808.

# %% [markdown]
# Lets see the distance of the movies from first movie.

# %%
# Retrieving the first movie
newdf.iloc[0].title
# Out:
# 'Avatar'

# %% [markdown]
# Lets see the distances from the movie **Avatar** with every other movies.

# %%
similarity[0]
# Out:
# array([1.        , 0.10910895, 0.10050378, ..., 0.        , 0.05287011,
#        0.        ])

# %% [markdown]
# The distance between Avatar and Avatar is 1, Avatar and Second movie is 0.1091 and so on. Now lets sort the values and see the top movies with greatest similarity.

# %%
def recommend(movie):
    if newdf[newdf['title'] == movie].empty :
        print(f"{movie} not present in the database")
    else:
        movie_index = newdf[newdf['title'] == movie].index[0]
        distances = similarity[movie_index]
        movies_list = sorted(list(enumerate(distances)),reverse=True , key = lambda x : x[1])[1:6]
        print("Top picks for you: \n")
        for i in movies_list :
            display(movpre.iloc[i[0]][['title','release_date','runtime','crew']])

# %%
recommend('Avatar')
# Out:
# Top picks for you:
# title                    Aliens
# release_date             [1986]
# runtime                   137.0
# crew            [James Cameron]
# Name: 2409, dtype: object
# title           Guardians of the Galaxy
# release_date                     [2014]
# runtime                           121.0
# crew                       [James Gunn]
# Name: 94, dtype: object
# title           The Helix... Loaded
# release_date                 [2005]
# runtime                        97.0
# crew                             []
# Name: 4407, dtype: object
# title           Transformers: Revenge of the Fallen
# release_date                                 [2009]
# runtime                                       150.0
# crew                                  [Michael Bay]
# Name: 35, dtype: object
# title           Capricorn One
# release_date           [1977]
# runtime                 123.0
# crew            [Peter Hyams]
# Name: 3676, dtype: object

# %%
recommend('Batman')
# Out:
# Top picks for you:
# title                          Batman
# release_date                   [1989]
# runtime                         126.0
# crew            [Leslie H. Martinson]
# Name: 1364, dtype: object
# title                 Batman
# release_date          [1966]
# runtime                105.0
# crew            [Tim Burton]
# Name: 1363, dtype: object
# title              The R.M.
# release_date         [2003]
# runtime               101.0
# crew            [Kurt Hale]
# Name: 4532, dtype: object
# title               Code of Honor
# release_date               [2016]
# runtime                     106.0
# crew            [Michael Winnick]
# Name: 3311, dtype: object
# title               Big Fish
# release_date          [2003]
# runtime                125.0
# crew            [Tim Burton]
# Name: 583, dtype: object

# %% [markdown]
# # Conclusion
# We pass the movie we have watches as the parameter into the model and then we get the top 5 movie recommendations using content-based filtering.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=8c70d09b-fa01-4bf5-b4e2-3efedd65dd42' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
